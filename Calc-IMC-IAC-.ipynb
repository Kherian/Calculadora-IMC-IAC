# %% [markdown]
# <a href="https://colab.research.google.com/github/Kherian/Calculadora-IMC-IAC/blob/master/Calc-IMC-IAC-.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Cálculo de IMC
#IMC = peso/altura^2
#precisa: peso, altura, idade e sexo
#ideal = 18.5 até 24.9
#ideal seria entre x e y tal que 18.5 = x / altura^2 e 24.9 = y / altura^2

# Cálculo de IAC
#IAC = circunferência do quadril / altura x raiz quadrada da altura
#precisa: circunferência do quadril, altura e sexo
#ideal: se H entre 8 e 20 
#ideal: se M entre 21 e 32

#### Nome
nome = input("Qual seu primeiro nome? ")
nome = nome.title()

sobrenome = input("Qual seu último nome? ")
sobrenome = sobrenome.title()

print_nome = "Nome Completo: " + nome + " " + sobrenome

#### Sexo

sex = input("Qual seu sexo? (H/M) ")
sex = sex.upper()
while sex != "H" and sex != "M":
  sex = input("Se for 'Homem', digite apenas 'H' \n Se for 'Mulher', digite apenas 'M' \n ")
  sex = sex.upper()
if sex == "H":
  print_sex = "Sexo: Masculino"
if sex == "M":
  print_sex = "Sexo: Feminino" 

### Idade

idade = input("Qual sua idade? (digite apenas o valor numérico em anos) ")
while idade.isnumeric() == False:
  idade = input("Novamente... Qual sua idade? \n Lembre-se: digite apenas o valor numérico em anos \n Por exemplo, se for '99 anos', digite apenas '99' \n ")

print_idade = "Idade: " + str(idade) + " anos"

### Altura

alt = input("Qual sua altura? (digite apenas o valor numérico em cm) ")
while alt.isnumeric() == False:
  alt = input("Novamente... Qual sua altura? \n Lembre-se de digitar apenas o valor numérico em cm \n Por exemplo, se for '2.70 metros', digite apenas '270' \n ")

alt_c = float(alt)
alt_m = alt_c / 100

print_alt = "Altura: " + str(alt_m) + " metros"

#### Peso

peso = input("Qual seu peso? (digite apenas o valor numérico em kg) ")
while peso.isnumeric() == False:
  peso = input("Novamente... Qual seu peso? \n Lembre-se de digitar apenas o valor numérico em kg \n Por exemplo, se for '380 kg', digite apenas '380' \n ")

p_peso = input("E você gostaria de perder peso? (S/N) ")
while p_peso.upper() != "S" and p_peso.upper() != "N":
  p_peso = input("E você gostaria de perder peso? (S/N) ")

qp_peso = input("Quantos kg gostaria de perder? ")
while qp_peso.isnumeric() == False:
  qp_peso = input("Quantos kg gostaria de perder? ")

###### Quadril #####

quad = input("Qual a circunferência do seu quadril? (digite apenas o valor numérico em cm) ")
while quad.isnumeric() == False:
  quad = input("Novamente... Qual a circunferência do seu quadril? \n Lembre-se: digite apenas o valor numérico em cm \n Por exemplo, se for '3,40 metro's, digite apenas '340' \n ")

p_quad = input("E você gostaria de perder quadril? (S/N) ")
while p_quad.upper() != "S" and p_quad.upper() != "N":
  p_quad = input("E você gostaria de perder quadril? (S/N) ")

if p_quad == "S":
  qp_quad = input("Qual tamanho gostaria de ter? ")
  while qp_quad.isnumeric() == False:
    qp_quad = input("Qual tamanho gostaria de ter? ")

### IMC
imc = float(peso) / ( float(alt_m) * float(alt_m))
imc = round(imc,2)

### IAC
iac = ( float(quad) / ( float(alt_m) * ( float(alt_m) ** 0.5))) - 18
iac = round(iac,2)

### Resultados IAC: Índice de Adiposidade Corporal
if  sex == "H" and iac >= 8 and 20 >= iac:
  user_iac = "Avaliação: Normal (entre 8 e 20)"

if  sex == "H" and iac >= 21 and 25 > iac:
  user_iac = "Avaliação: Sobrepeso (entre 21 e 25)"

if  sex == "H" and iac > 25:
  user_iac = "Avaliação: Obeso (acima de 25)"

if sex == "M" and iac >= 21 and 32 >= iac:
  user_iac = "Avaliação: Normal (entre 21 e 32)"

if sex == "M" and iac >= 33 and 38 > iac:
  user_iac = "Avaliação: Sobrepeso (entre 33 e 38)"

if sex == "M" and iac >= 38:
  user_iac = "Avaliação: Obeso (acima de 38)"

#### IAC IDEAL:

iac_H_mi = ((float(alt_m) * ( float(alt_m) ** 0.5))*(8+18))
iac_H_ma = ((float(alt_m) * ( float(alt_m) ** 0.5))*(20+18))

iac_M_mi = ((float(alt_m)*( float(alt_m) ** 0.5))*(21+18))
iac_M_ma = ((float(alt_m)*( float(alt_m) ** 0.5))*(32+18))

if sex == "H":
  quad_min = round(iac_H_mi,2)
  quad_max = round(iac_H_ma,2)

if sex == "M":
  quad_min = round(iac_M_mi,2)
  quad_max = round(iac_M_ma,2)

### Resultados IMC: Índice de Massa Corporal
if imc < 18.5:
  user_imc = "Avaliação: Abaixo do peso (abaixo de 18.5)"

if imc >= 18.5 and imc <= 24.9:
  user_imc = "Avaliação: Peso normal (entre 18.5 e 24.9)"  

if imc >= 25.0 and imc <= 29.9:
  user_imc = "Avaliação: Sobrepeso (entre 25.0 e 29.9)"

if imc >= 30.0 and imc <= 34.9:
  user_imc = "Avaliação: Obesidade Tipo I (entre 30.0 e 34.9)"

if imc >= 35.0 and imc <= 39.9:
  user_imc = "Avaliação: Obesidade Tipo II (entre 35.5 e 39.9 )"

if imc >= 40.0:
  user_imc = "Avaliação: Obesidade Mórbida Tipo III (acima de 40.0)"

### IMC IDEAL:

peso_min = ((float(alt_m) * float(alt_m))*18.5)
peso_min = round(peso_min,2)

peso_max = ((float(alt_m) * float(alt_m))*24.9)
peso_max = round(peso_max,2)

########## PRINTS

# Quadril

if p_quad.upper() == "S" and float(quad) >= float(quad_min) and float(quad) <= float(quad_max):
  print_quad = "Quadril Atual: " + str(quad) + "cm --- Quadril Desejado: " + str(qp_quad) + "cm --- Não é necessário perder quadril (veja abaixo)"

if p_quad.upper() == "S" and float(qp_quad) < float(quad_min) and float(quad) < float(quad_min):
  print_quad = "Quadril Atual: " + str(quad) + "cm --- Quadril Desejado: " + str(qp_quad) + "cm --- Precisa ganhar mais quadril que isso (veja abaixo)"

if p_quad.upper() == "S" and float(qp_quad) == float(quad_min) and float(quad) < float(quad_min):
  print_quad = "Quadril Atual: " + str(quad) + "cm --- Quadril Desejado: " + str(qp_quad) + "cm --- Precisa ganhar exatamente isso (veja abaixo)"

if p_quad.upper() == "S" and float(qp_quad) > float(quad_max) and float(quad) > float(quad_max):
  print_quad = "Quadril Atual: " + str(quad) + "cm --- Quadril Desejado: " + str(qp_quad) + "cm --- Precisa perder mais quadril que isso (veja abaixo)"

if p_quad.upper() == "S" and float(qp_quad) == float(quad_max) and float(quad) > float(quad_max):
  print_quad = "Quadril Atual: " + str(quad) + "cm --- Quadril Desejado: " + str(qp_quad) + "cm --- Precisa perder exatamente isso (veja abaixo)"  

#

if p_quad.upper() == "N" and float(quad) >= float(quad_min) and float(quad) <= float(quad_max):
  print_quad = "Quadril Atual: " + str(quad) + "cm " + "--- Não é necessário perder quadril (veja abaixo)"

if p_quad.upper() == "N" and float(qp_quad) < float(quad_min) and float(quad) < float(quad_min):
  print_quad = "Quadril Atual: " + str(quad) + "cm " + "--- Precisa ganhar mais quadril que isso (veja abaixo)"

if p_quad.upper() == "N" and float(qp_quad) > float(quad_max) and float(quad) > float(quad_max):
  print_quad = "Quadril Atual: " + str(quad) + "cm " + "--- Precisa perder mais quadril que isso (veja abaixo)"


# Peso 

peso_desejado = int(peso) - int(qp_peso)



if p_peso.upper() == "S" and float(peso) >= float(peso_min) and float(peso) <= float(peso_max):
  print_peso = "Peso Atual: " + str(peso) + "kg --- Peso Desejado: " + str(peso_desejado) + "kg -- Não é necessário perder ou ganhar peso (veja abaixo)"

if p_peso.upper() == "S" and float(peso_desejado) < float(peso_min) and float(peso) < float(peso_min):
  print_peso = "Peso Atual: " + str(peso) + "kg --- Peso Desejado: " + str(peso_desejado) + "kg -- Precisa ganhar " + str(round((float(peso_min) - float(peso)), 2)) + "kg, não perder peso (veja abaixo)"

if p_peso.upper() == "S" and float(peso_desejado) == float(peso_max) and float(peso) > float(peso_max):
  print_peso = "Peso Atual: " + str(peso) + "kg --- Peso Desejado: " + str(peso_desejado) + "kg -- Precisa perder exatamente " + qp_peso + "kg (veja abaixo)"

if p_peso.upper() == "S" and float(peso_desejado) > float(peso_max) and float(peso) > float(peso_max):
  print_peso = "Peso Atual: " + str(peso) + "kg --- Peso Desejado: " + str(peso_desejado) + "kg -- Precisa perder mais do que " + qp_peso + "kg (veja abaixo)"

if p_peso.upper() == "S" and float(peso_desejado) < float(peso_min) and float(peso) > float(peso_max):
  print_peso = "Peso Atual: " + str(peso) + "kg --- Peso Desejado: " + str(peso_desejado) + "kg -- Precisa perder menos que " + qp_peso + "kg (veja abaixo)"

#

if p_peso.upper() == "N" and float(peso) >= float(peso_min) and float(peso) <= float(peso_max):
  print_peso = "Peso Atual: " + str(quad) + "kg " + "--- Não é necessário perder quadril (veja abaixo)"

if p_peso.upper() == "N" and float(peso) < float(peso_min):
  print_peso = "Peso Atual: " + str(quad) + "kg " + "--- Precisa ganhar peso (veja abaixo)"

if p_peso.upper() == "N" and float(peso) > float(peso_max):
  print_peso = "Peso Atual: " + str(quad) + "kg " + "--- Precisa perder peso (veja abaixo)"


#### Saída com os dados:
print("\n \n" + print_nome + "\n" + print_idade + "\n" + print_sex + "\n" + print_alt + "\n" + print_peso + "\n" + print_quad + "\n")

###### Resultados:
print("Resultados:")

## Resultados IMC:

if p_peso.upper() == "N" and float(peso) <= float(peso_max) and float(peso) >= float(peso_min):
  print("Índice de Massa Corporal (IMC) \n" + "Seu IMC é de: " + str(round(imc, 1)) + "\n" + user_imc + "\n"
  "Seu peso ideal, para sua altura, seria entre " + str(round(float(peso_min), 1)) + "kg e " + str(round(float(peso_max), 1)) + "kg \n" +
  "Parabéns! Você está dentro do peso ideal!" + "\n")

if p_peso.upper() == "N" and float(peso) > float(peso_max):
  print("Índice de Massa Corporal (IMC) \n" + "Seu IMC é de: " + str(round(imc, 1)) + "\n" + user_imc + "\n"
  "Seu peso ideal, para sua altura, seria entre " + str(round(float(peso_min), 1)) + "kg e " + str(round(float(peso_max), 1)) + "kg \n" +
  "Precisa perder ao menos: " + str(round((float(peso) - float(peso_max)), 2)) + "kg para atingir isso" + "\n")

if p_peso.upper() == "N" and float(peso) < float(peso_min):
  print("Índice de Massa Corporal (IMC) \n" + "Seu IMC é de: " + str(round(imc, 1)) + "\n" + user_imc + "\n"
  "Seu peso ideal, para sua altura, seria entre " + str(round(float(peso_min), 1)) + "kg e " + str(round(float(peso_max), 1)) + "kg \n" +
  "Precisa ganhar ao menos: " + str(round((float(peso_min) - float(peso)), 2)) + "kg para atingir isso" + "\n")

if p_peso.upper() == "S" and float(peso) > float(peso_max):
  print("Índice de Massa Corporal (IMC) \n" + "Seu IMC é de: " + str(round(imc, 1)) + "\n" + user_imc + "\n" +
        "Seu peso ideal, para sua altura, seria entre " + str(round(float(peso_min), 1)) + "kg e " + str(round(float(peso_max), 1)) + "kg \n" +
        "Precisa perder ao menos: " + str(round(float(peso)-float(peso_max), 2)) + "kg para atingir isso" + "\n")

if p_peso.upper() == "S" and float(peso) <= float(peso_max):
  print("Índice de Massa Corporal (IMC) \n" + "Seu IMC é de: " + str(round(imc, 1)) + "\n " + user_imc + "\n" +
        "Seu peso ideal, para sua altura, seria entre " + str(round(float(peso_min), 1)) + "kg e " + str(round(float(peso_max), 1)) + "kg \n" +
        "Como seu peso é de " + peso + " kg, você não precisa perder peso -- relaxe!" + "\n")



## Resultados IAC:

if p_quad.upper() == "N" and float(quad) <= float(quad_max) and float(quad) >= float(quad_min):
  print("Índice de Adiposidade Corporal (IAC) \n" + "Seu IAC é de: " + str(round(iac, 1)) + "% \n" + user_iac + "\n" +
        "Seu quadril ideal, para sua altura, seria entre " + str(float(quad_min)) + "cm e " + str(float(quad_max)) + "cm \n" +
        "Parabéns! Você está dentro do peso ideal!" + "\n")

if p_quad.upper() == "N" and float(quad) > float(quad_max):
  print("Índice de Adiposidade Corporal (IAC) \n" + "Seu IAC é de: " + str(round(iac, 1)) + "% \n" + user_iac + "\n" +
        "Seu quadril ideal, para sua altura, seria entre " + str(float(quad_min)) + "cm e " + str(float(quad_max)) + "cm \n" +
        "Precisa perder ao menos: " + str(round((float(quad) - float(peso_max)), 2)) + "cm para atingir isso" + "\n")

if p_quad.upper() == "N" and float(quad) < float(quad_min):
  print("Índice de Adiposidade Corporal (IAC) \n" + "Seu IAC é de: " + str(round(iac, 1)) + "% \n" + user_iac + "\n" +
        "Seu quadril ideal, para sua altura, seria entre " + str(float(quad_min)) + "cm e " + str(float(quad_max)) + "cm \n" +
        "Precisa ganhar ao menos: " + str(round((float(quad_min) - float(quad)), 2)) + "cm para atingir isso" + "\n")

if p_quad.upper() == "S" and float(quad) > float(quad_max):
  print("Índice de Adiposidade Corporal (IAC) \n" + "Seu IAC é de: " + str(round(iac, 1)) + "% \n" + user_iac + "\n" +
        "Seu quadril ideal, para sua altura, seria entre " + str(float(quad_min)) + "cm e " + str(float(quad_max)) + "cm \n" +
        "Precisa perder ao menos: " + str(round((float(quad) - float(quad_max)), 2)) + "cm para atingir isso" + "\n")

if p_quad.upper() == "S" and float(quad) <= float(quad_max):
  print("Índice de Adiposidade Corporal (IAC) \n" + "Seu IAC é de: " + str(round(iac, 1)) + "% \n" + user_iac + "\n" +
        "Seu quadril ideal, para sua altura, seria entre " + str(float(quad_min)) + "cm e " + str(float(quad_max)) + "cm \n" +
        "Como seu quadril é de " + quad + "cm, você não precisa perder -- relaxe!" + "\n")


input("Obrigado por usar meu primeiro programinha em Python <3 \n Oferecimento: Kherian Gracher \n \n -- aperte qualquer tecla para fechar --")
# Out:
# Qual seu primeiro nome? kherian
# Qual seu último nome? gracher
# Qual seu sexo? (H/M) m
# Qual sua idade? (digite apenas o valor numérico em anos) 20
# Qual sua altura? (digite apenas o valor numérico em cm) 140
# Qual seu peso? (digite apenas o valor numérico em kg) 99
# E você gostaria de perder peso? (S/N) s
# Quantos kg gostaria de perder? 40
# Qual a circunferência do seu quadril? (digite apenas o valor numérico em cm) 99
# E você gostaria de perder quadril? (S/N) s
# Qual tamanho gostaria de ter? 60
#
#
# Nome Completo: Kherian Gracher
# Idade: 20 anos
# Sexo: Feminino
# 1.4 metros
# Peso Atual: 99kg --- Peso Desejado: 59kg -- Precisa perder mais do que 40kg (veja abaixo)
# Quadril Atual: 55cm --- Quadril Desejado: 50cm --- Não é necessário perder quadril (veja abaixo)
#
# Resultados:
# Índice de Massa Corporal (IMC)
# Seu IMC é de: 50.5
# Avaliação: Obesidade Mórbida Tipo III (acima de 40.0)
# Seu peso ideal, para sua altura, seria entre 36.3 e 48.8
# ...
